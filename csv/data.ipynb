# %%
import pandas as pd

# %% [markdown]
# первый док

# %%
data1 = pd.read_excel(r'tables_excel\Material_type_import.xlsx')
data1.to_csv(r'tables_csv\Material_type_import.csv', sep=';', index=True)

# %% [markdown]
# второй док

# %%
data2 = pd.read_excel(r'tables_excel\Product_type_import.xlsx')
data2.to_csv(r'tables_csv\Product_type_import.csv', sep=';', index=True)

# %% [markdown]
# третий док

# %%
data3 = pd.read_excel(r'tables_excel\Product_workshops_import.xlsx')
data3.to_csv(r'tables_csv\Product_workshops_import.csv', sep=';', index=True)

# %% [markdown]
# 4ый лок

# %%
data4 = pd.read_excel(r'tables_excel\Products_import.xlsx')
data4.to_csv(r'tables_csv\Products_import.csv', sep=';', index=True)

# %% [markdown]
# пятый док

# %%
data5 = pd.read_excel(r'tables_excel\Workshops_import.xlsx')
data5.to_csv(r'tables_csv\Workshops_import.csv', sep=';', index=True)
