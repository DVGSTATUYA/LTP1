# %%
import pandas as pd
#1
dt1 = pd.read_excel(r'Material_type_import.xlsx')
dt1.to_csv(r'Material_type_import.csv', sep=';', index=True)
#2
dt2 = pd.read_excel(r'Product_type_import.xlsx')
dt2.to_csv(r'Product_type_import.csv', sep=';', index=True)
#3
dt3 = pd.read_excel(r'Product_workshops_import.xlsx')
dt3.to_csv(r'Product_workshops_import.csv', sep=';', index=True)
#4
dt4 = pd.read_excel(r'Products_import.xlsx')
dt4.to_csv(r'Products_import.csv', sep=';', index=True)
#5
dt5 = pd.read_excel(r'Workshops_import.xlsx')
dt5.to_csv(r'Workshops_import.csv', sep=';', index=True)
